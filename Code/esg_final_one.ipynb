# %%
s = '''appdirs==1.4.4
argon2-cffi==20.1.0
async-generator==1.10
attrs==20.3.0
backcall==0.2.0
beautifulsoup4==4.10.0
bleach==3.3.0
boto3==1.16.7
botocore==1.19.7
bs4==0.0.1
certifi==2020.12.5
cffi==1.14.5
chardet==4.0.0
csrgraph==0.1.28
cycler==0.10.0
Cython==0.29.23
dbus-python==1.2.16
decorator==5.0.6
defusedxml==0.7.1
distlib==0.3.2
distro==1.4.0
distro-info===0.23ubuntu1
entrypoints==0.3
facets-overview==1.0.0
filelock==3.0.12
gdelt==0.1.10.5.3
gensim==3.6.0
idna==2.10
ipykernel==5.3.4
ipython==7.22.0
ipython-genutils==0.2.0
ipywidgets==7.6.3
jedi==0.17.2
Jinja2==2.11.3
jmespath==0.10.0
joblib==1.0.1
jsonschema==3.2.0
jupyter-client==6.1.12
jupyter-core==4.7.1
jupyterlab-pygments==0.1.2
jupyterlab-widgets==1.0.0
kiwisolver==1.3.1
koalas==1.8.1
llvmlite==0.38.0
MarkupSafe==1.1.1
matplotlib==3.4.2
mistune==0.8.4
nbclient==0.5.3
nbconvert==6.0.7
nbformat==5.1.3
nest-asyncio==1.5.1
networkx==2.7.1
nodevectors==0.1.23
notebook==6.3.0
numba==0.55.1
numpy==1.21.0
packaging==20.9
pandas==1.2.4
pandocfilters==1.4.3
parso==0.7.0
patsy==0.5.1
pexpect==4.8.0
pickleshare==0.7.5
Pillow==8.2.0
plotly==5.1.0
prometheus-client==0.10.1
prompt-toolkit==3.0.17
protobuf==3.17.2
psycopg2==2.8.5
ptyprocess==0.7.0
pyarrow==4.0.0
pycparser==2.20
Pygments==2.8.1
PyGObject==3.36.0
pyparsing==2.4.7
pyrsistent==0.17.3
python-apt==2.0.0+ubuntu0.20.4.7
python-dateutil==2.8.1
pytz==2020.5
pyzmq==20.0.0
requests==2.25.1
requests-unixsocket==0.2.0
s3transfer==0.3.7
scikit-learn==0.24.1
scipy==1.8.0
seaborn==0.11.1
Send2Trash==1.5.0
six==1.16.0
smart-open==5.2.1
soupsieve==2.3.1
ssh-import-id==5.10
statsmodels==0.12.2
tenacity==8.0.1
terminado==0.9.4
testpath==0.4.4
threadpoolctl==2.1.0
tornado==6.1
tqdm==4.63.1
traitlets==5.0.5
unattended-upgrades==0.1
urllib3==1.25.11
virtualenv==20.4.1
wcwidth==0.2.5
webencodings==0.5.1
widgetsnbextension==3.5.1'''


for i in s.split('\n'):
    # !pip3 install i
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Collecting i
#   Downloading i-2.1.0-py2.py3-none-any.whl (8.0 kB)
# Collecting colorama&gt;=0.3.9
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Collecting asttokens&gt;=2.0.1
#   Downloading asttokens-2.0.8-py2.py3-none-any.whl (23 kB)
# Collecting executing&gt;=0.3.1
#   Downloading executing-1.0.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# Installing collected packages: executing, colorama, asttokens, i
# Successfully installed asttokens-2.0.8 colorama-0.4.5 executing-1.0.0 i-2.1.0
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requiremen

# %%
s='''altair==4.2.0
argon2-cffi==21.3.0
argon2-cffi-bindings==21.2.0
asttokens==2.0.5
attrs==21.4.0
backcall==0.2.0
backports.zoneinfo==0.2.1
beautifulsoup4==4.10.0
bleach==4.1.0
blinker==1.4
cachetools==5.0.0
certifi==2021.10.8
cffi==1.15.0
charset-normalizer==2.0.12
click==8.0.4
colorama==0.4.4
colour==0.1.5
debugpy==1.6.0
decorator==5.1.1
defusedxml==0.7.1
entrypoints==0.4
executing==0.8.3
gitdb==4.0.9
GitPython==3.1.27
idna==3.3
importlib-metadata==4.11.3
importlib-resources==5.4.0
ipykernel==6.9.2
ipython==8.0.1
ipython-genutils==0.2.0
ipywidgets==7.7.0
jedi==0.18.1
Jinja2==3.1.0
jsonschema==4.4.0
jupyter-client==7.1.2
jupyter-core==4.9.2
jupyterlab-pygments==0.1.2
jupyterlab-widgets==1.1.0
MarkupSafe==2.1.1
matplotlib-inline==0.1.3
metadata-parser==0.10.5
mistune==0.8.4
nbclient==0.5.13
nbconvert==6.4.4
nbformat==5.2.0
nest-asyncio==1.5.4
notebook==6.4.10
numpy==1.22.3
packaging==21.3
pandas==1.4.1
pandocfilters==1.5.0
parso==0.8.3
pickleshare==0.7.5
Pillow==9.0.1
plotly==5.6.0
prometheus-client==0.13.1
prompt-toolkit==3.0.28
protobuf==3.19.4
psutil==5.9.0
pure-eval==0.2.2
pyarrow==7.0.0
pycparser==2.21
pydeck==0.7.1
Pygments==2.11.2
Pympler==1.0.1
pyparsing==3.0.7
pyrsistent==0.18.1
python-dateutil==2.8.2
pytz==2022.1
pytz-deprecation-shim==0.1.0.post0
pyzmq==22.3.0
requests==2.27.1
requests-toolbelt==0.9.1
scipy==1.8.0
semver==2.13.0
Send2Trash==1.8.0
six==1.16.0
smmap==5.0.0
soupsieve==2.3.1
stack-data==0.2.0
streamlit==1.8.0
tabulate==0.8.9
tenacity==8.0.1
terminado==0.13.3
testpath==0.6.0
toml==0.10.2
toolz==0.11.2
tornado==6.1
traitlets==5.1.1
tzdata==2022.1
tzlocal==4.1
urllib3==1.26.9
validators==0.18.2
watchdog==2.1.6
wcwidth==0.2.5
webencodings==0.5.1
widgetsnbextension==3.6.0
zipp==3.7.0'''
for i in s.split('\n'):
    # !pip install i
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygments&gt;=2.2.0 in /databricks/python3/lib/python3.8/site-packages (from i) (2.8.1)
# Requirement already satisfied: asttokens&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from i) (2.0.8)
# Requirement already satisfied: executing&gt;=0.3.1 in /databricks/python3/lib/python3.8/site-packages (from i) (1.0.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.8/site-packages (from asttokens&gt;=2.0.1-&gt;i) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: i in /databricks/python3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: colorama&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from i) (0.4.5)
# Requirement already satisfied: pygment

# %%
# !pip3 install gdelt
# !pip install bs4
# !pip install nodevectors
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Collecting gdelt
#   Downloading gdelt-0.1.10.6.1-py2.py3-none-any.whl (773 kB)
#      |████████████████████████████████| 773 kB 936 kB/s
# <span class="ansi-yellow-fg">WARNING: Discarding https://files.pythonhosted.org/packages/65/f9/a3d5111c8f17334b1752c32aedaab0d01ab4324bf26417bd41890d5b25d0/gdelt-0.1.10.6.1-py2.py3-none-any.whl#sha256=e69467f944c9eeab1648244fb58e9c4b6e073a5a0d16c3cdf8f99c0c8c290f6a (from https://pypi.org/simple/gdelt/). Requested gdelt from https://files.pythonhosted.org/packages/65/f9/a3d5111c8f17334b1752c32aedaab0d01ab4324bf26417bd41890d5b25d0/gdelt-0.1.10.6.1-py2.py3-none-any.whl#sha256=e69467f944c9eeab1648244fb58e9c4b6e073a5a0d16c3cdf8f99c0c8c290f6a has inconsistent version: filename has &#39;0.1.10.6.1&#39;, but metadata has &#39;0.1.10.6&#39;</span>
#   Downloading gdelt-0.1.10.6.1.tar.gz (982 kB)
#      |████████████████████████████████| 982 kB 47.9 MB/s
# <span class="ansi-red-fg">    ERROR: Command errored out with exit status 1:
#      command: /databricks/python3/bin/python -c &#39;import sys, setuptools, tokenize; sys.argv[0] = &#39;&#34;&#39;&#34;&#39;/tmp/pip-install-7vwzvd0r/gdelt_d46e5bc4627b4f4eb07c5a2483865cc4/setup.py&#39;&#34;&#39;&#34;&#39;; __file__=&#39;&#34;&#39;&#34;&#39;/tmp/pip-install-7vwzvd0r/gdelt_d46e5bc4627b4f4eb07c5a2483865cc4/setup.py&#39;&#34;&#39;&#34;&#39;;f=getattr(tokenize, &#39;&#34;&#39;&#34;&#39;open&#39;&#34;&#39;&#34;&#39;, open)(__file__);code=f.read().replace(&#39;&#34;&#39;&#34;&#39;\r\n&#39;&#34;&#39;&#34;&#39;, &#39;&#34;&#39;&#34;&#39;\n&#39;&#34;&#39;&#34;&#39;);f.close();exec(compile(code, __file__, &#39;&#34;&#39;&#34;&#39;exec&#39;&#34;&#39;&#34;&#39;))&#39; egg_info --egg-base /tmp/pip-pip-egg-info-lv3octgh
#          cwd: /tmp/pip-install-7vwzvd0r/gdelt_d46e5bc4627b4f4eb07c5a2483865cc4/
#     Complete output (9 lines):
#     Traceback (most recent call last):
#       File &#34;&lt;string&gt;&#34;, line 1, in &lt;module&gt;
#       File &#34;/tmp/pip-install-7vwzvd0r/gdelt_d46e5bc4627b4f4eb07c5a2483865cc4/setup.py&#34;, line 39, in &lt;module&gt;
#         read(&#39;CHANGES&#39;)),
#       File &#34;/tmp/pip-install-7vwzvd0r/gdelt_d46e5bc4627b4f4eb07c5a2483865cc4/setup.py&#34;, line 15, in read
#         with codecs.open(os.path.join(cwd, filename), &#39;rb&#39;, &#39;utf-8&#39;) as h:
#       File &#34;/usr/lib/python3.8/codecs.py&#34;, line 905, in open
#         file = builtins.open(filename, mode, buffering)
#     FileNotFoundError: [Errno 2] No such file or directory: &#39;/tmp/pip-install-7vwzvd0r/gdelt_d46e5bc4627b4f4eb07c5a2483865cc4/CHANGES&#39;
#     ----------------------------------------</span>
# <span class="ansi-yellow-fg">WARNING: Discarding https://files.pythonhosted.org/packages/95/1f/c62e819f54c7a9d6cc74ab1924972c59121cd042dbac54da5ead2da9612d/gdelt-0.1.10.6.1.tar.gz#sha256=3da32cb33a2d490f1441b41c71cc2e006cabb074c245db31e5960c7eb4973316 (from https://pypi.org/simple/gdelt/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.</span>
#   Downloading gdelt-0.1.10.5.3-py2.py3-none-any.whl (761 kB)
#      |████████████████████████████████| 761 kB 65.5 MB/s
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.8/site-packages (from gdelt) (1.20.1)
# Requirement already satisfied: requests in /databricks/python3/lib/python3.8/site-packages (from gdelt) (2.25.1)
# Requirement already satisfied: python-dateutil in /databricks/python3/lib/python3.8/site-packages (from gdelt) (2.8.1)
# Requirement already satisfied: pandas&gt;=0.20.3 in /databricks/python3/lib/python3.8/site-packages (from gdelt) (1.2.4)
# Requirement already satisfied: pytz&gt;=2017.3 in /databricks/python3/lib/python3.8/site-packages (from pandas&gt;=0.20.3-&gt;gdelt) (2020.5)
# Requirement already satisfied: six&gt;=1.5 in /databricks/python3/lib/python3.8/site-packages (from python-dateutil-&gt;gdelt) (1.15.0)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests-&gt;gdelt) (1.25.11)
# Requirement already satisfied: idna&lt;3,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests-&gt;gdelt) (2.10)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests-&gt;gdelt) (2020.12.5)
# Requirement already satisfied: chardet&lt;5,&gt;=3.0.2 in /databricks/python3/lib/python3.8/site-packages (from requests-&gt;gdelt) (4.0.0)
# Installing collected packages: gdelt
# Successfully installed gdelt-0.1.10.5.3
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 1.1 MB/s
# Collecting soupsieve&gt;1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Building wheels for collected packages: bs4
# done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=c0f5ab0cb211dbd69fef0286231f64aed7d4ccf75b88ab8092013d3d5b3c6985
#   Stored in directory: /root/.cache/pip/wheels/75/78/21/68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.11.1 bs4-0.0.1 soupsieve-2.3.2.post1
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Collecting nodevectors
#   Downloading nodevectors-0.1.23.tar.gz (15 kB)
# Collecting csrgraph
#   Downloading csrgraph-0.1.28.tar.gz (14 kB)
# Collecting gensim
#   Downloading gensim-4.2.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.1 MB)
#      |█▋

# %%
# Databricks notebook source
import gdelt
import os
import datetime
from collections import Counter
from pprint import pprint
import pandas as pd
import pyspark.sql.functions as F
from pyspark.sql import DataFrame as spark_DataFrame
from pyspark.sql.types import *
from functools import reduce
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
import re
from itertools import product
import time
import pandas as pd 
from io import BytesIO
import requests


# COMMAND ----------

def also_call_as(c):
    """
    Make a list of aliases for a given company using a few predefined
    rules. Try to encompass as many options as possible keeping in mind
    there will be aliases left out.
    """
    c = c.lower()

    # URLs (e.g. ".com")
    if len(c) > 3 and c[-4] == ".":
        a = c
        c = c.rsplit(".", 1)[0].replace(".", " ")
        aliases = set([c, a])
    else:
        aliases = set([c])

    # Single letter endings
    if len(c.split()[-1]) == 1:
        c = c.rsplit(" ", 1)[0]
        aliases.add(c)

    # Company legal endings
    endings = ["inc", "corp", "plc", "reit", "co", "cor", "group", "company",
               "trust", "energy", "international", "of america", "pharmaceuticals",
               "clas", "in", "nv", "sa", "re"]
    n_endings = 3  # Can have up to 3 of these endings
    for _ in range(n_endings):
        aliases.update([a.rsplit(" ", 1)[0] for a in aliases if
                        any([a.endswith(" " + e) for e in endings])])
        c = c.rsplit(" ", 1)[0] if any([c.endswith(" " + e) for e in endings]) else c

    # Alias any dashes and replace in company name
    aliases.update([a.replace("-", "") for a in aliases] +
                   [a.replace("-", " ") for a in aliases])
    c = c.replace("-", " ")

    # If '&' stands on its own, add alias of 'and'
    aliases.update([a.replace(" & ", " and ") for a in aliases])

    return {c: list(aliases)}


def generate_common_org_names(org_name):
    """
    Download the companies and loop through them to find their aliases
    """
    companies = [org_name]
    comp_dict = dict()
    for c in companies:
        comp_dict.update(also_call_as(c))
    return comp_dict

# COMMAND ----------

combine_spark_dfs = lambda sdf_list: reduce(spark_DataFrame.union, sdf_list)

class Common_MetaData:
    """ Variables to use across many functions. """
    keep = ["DATE", "SourceCommonName", "DocumentIdentifier", "Themes",
            "Organizations", "V2Tone"]
    tone = ["Tone", "PositiveTone", "NegativeTone", "Polarity",
            "ActivityDensity", "SelfDensity", "WordCount"]
    organizations = None



@udf(ArrayType(StringType(), True))
def simple_expand_spark(x):
    """ Expand a semicolon separated strint to a list (ignoring empties)"""
    if not x:
        return []
    return list(filter(None, x.split(";")))



@udf(MapType(StringType(), DoubleType()))
def tone_expand_spark(x):
    """ Expand the tone field. """
    if not x:
        return {t: None for t in Common_MetaData.tone}
    return {Common_MetaData.tone[i]: float(v) for i, v in enumerate(x.split(","))}



@udf(BooleanType())
def has_theme_spark(x, theme):
    """ Is the given theme included in any of the listed themes? """
    return any([theme in lst.split("_") for lst in x])


@udf(StringType())
def clean_organization(s):
    """ Standardize the organization names. """
    for k, v in Common_MetaData.organizations.items():
        if s.lower() in v:
            return k
    return s.lower()



class Redesign_data_format:
    def redesign_sdf(self, sdf, org_name):
        """
        Given a spark data frame of the downloaded data, reformat it
        into human-readable Common_MetaData.
        Add a few more Common_MetaData for our purposes.
        """
        setattr(Common_MetaData, "organizations",generate_common_org_names(org_name))
        sdf = sdf.select(*Common_MetaData.keep)

        # Reformat existing columns
        sdf = (sdf.withColumnRenamed("DocumentIdentifier", "URL")
                  .withColumn("Themes", simple_expand_spark("Themes"))
                  .withColumn("Organizations", simple_expand_spark("Organizations"))
                  .withColumn("V2Tone", tone_expand_spark("V2Tone"))
               )

        # Create ESG columns & explode organization column
        sdf = (sdf.withColumn("E", has_theme_spark("Themes", F.lit("ENV")))
                  .withColumn("S", has_theme_spark("Themes", F.lit("UNGP")))
                  .withColumn("G", has_theme_spark("Themes", F.lit("ECON")))
                  .withColumn("Organization", F.explode("Organizations"))
                  .withColumn("Organization", clean_organization("organization"))
                  .filter(F.col("organization").isin(list(Common_MetaData.organizations.keys())))
               )

        # Expand tone columns
        exprs = [F.col("V2Tone").getItem(k).alias(k) for k in Common_MetaData.tone]

        sdf = sdf.select(*sdf.columns, *exprs).drop("V2Tone")
        return sdf


    def download_and_generate_gdelt_table1(self, date, gd):
        """
        Download the GDELT table as a pandas dataframe using the gdelt package.
        Return a spark data frame.
        """
        pdf = gd.Search([date], table="gkg",coverage=True, output="df")
        pdf["DATE"] = pd.to_datetime(pdf["DATE"], format="%Y%m%d%H%M%S")

        sdf = spark.createDataFrame(pdf)
        print("   * loaded *  ", date)
        return sdf
    def download_and_generate_gdelt_table(self, date ):
        li = ''.join(date.split('-'))
        response = requests.get('http://data.gdeltproject.org/gdeltv2/'+li+'234500.gkg.csv.zip')
        #'http://data.gdeltproject.org/gkg/20220204.gkg.csv.zip')
        buffer = BytesIO(response.content)

        
        frame = pd.read_csv(buffer, compression='zip', sep='\t',header=None, warn_bad_lines=True,encoding='latin')
        frame[1] = pd.to_datetime(frame[1], format="%Y%m%d%H%M%S")
        frame.columns = ['GKGRECORDID', 'DATE', 'SourceCollectionIdentifier', 'SourceCommonName',
           'DocumentIdentifier', 'Counts', 'V2Counts', 'Themes', 'V2Themes',
           'Locations', 'V2Locations', 'Persons', 'V2Persons', 'Organizations',
           'V2Organizations', 'V2Tone', 'Dates', 'GCAM', 'SharingImage',
           'RelatedImages', 'SocialImageEmbeds', 'SocialVideoEmbeds', 'Quotations',
           'AllNames', 'Amounts', 'TranslationInfo', 'Extras'] 
        sdf = spark.createDataFrame(frame)
        print("   * loaded *  ", date)
        return sdf


    def getting_all_org_data(self, start_date, end_date, organisation_name = None, override_save=False):
        """
        For each date between start_date and end_date, either download
        and clean the data or load the pre-saved data. Save the day's data
        in case of future use (so it doesn't have to be downloaded and cleaned again)
        """
        print("Loading and cleaning all data")
        data_list = []
        gd = gdelt.gdelt(version=2)

        # Download and format the daily data
        for i, date in enumerate(pd.date_range(start_date, end_date).astype(str)):
            if i % 7 == 1:
                # Prevent it hanging like it does sometimes
                time.sleep(60)

            try:
                df = self.redesign_sdf(self.download_and_generate_gdelt_table(date), organisation_name)      
                data_list.append(df)
                del df
                spark.catalog.clearCache()

            except Exception as e:
              print(f"!!! Failed to complete {date}!")
              print("  ****   Reason:\n" + str(e) + "\n\n")

        return combine_spark_dfs(data_list)

# COMMAND ----------

def download_gdelt_data(start_date, end_date, org_name = None, save_csv=True):
    """
    """
    dbutils.fs.rm('/mnt/esg/financial_report_data/GDELT_data_single_org', True)    
    base_dir = f"dbfs:/mnt/esg/financial_report_data/GDELT_data_single_org"

    dbutils.fs.mkdirs(base_dir)
    # Download and reformat the data
    data = Redesign_data_format().getting_all_org_data(start_date, end_date, org_name)
    print(f"There are {data.count():,d} data points for {len(Common_MetaData.organizations)} "
          f"organizations from {start_date} to {end_date}")

    # Save the data
    print("Saving Data...")
    data_save_path = f"dbfs:/mnt/esg/financial_report_data/GDELT_data_single_org/data_single_org" ## we are changing
    data.write.format("delta").mode("overwrite").save(data_save_path) ## need to remove this..
    print(f"Saved to {data_save_path}")

    return data

# COMMAND ----------
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Databricks notebook source
import os
from pprint import pprint
import pandas as pd
import numpy as np
import pyspark.sql.functions as F
from pyspark.sql import Window
import sys
import datetime


def singleSource(filtered_df):
    #Tone	PositiveTone	NegativeTone	Polarity	ActivityDensity	SelfDensity	WordCount
    filtered_df_result = (filtered_df.groupby(F.date_format("DATE", "y-MM-dd").alias("date"), 'SourceCommonName')
                                      .agg(F.mean("Tone"), F.mean("PositiveTone"), F.mean("NegativeTone"), 
                                           F.mean("Polarity"), F.mean("ActivityDensity"), 
                                           F.mean("SelfDensity"), F.mean("WordCount"))
                                      .withColumn("date", F.to_date("date", format="y-MM-dd"))
                                      .withColumn("date", F.col("date").cast("date"))
                                      .orderBy(F.col("date").asc())
                          )
    filtered_df_result = (filtered_df_result.select("date", "SourceCommonName", F.col("avg(Tone)").alias("Tone"), F.col("avg(PositiveTone)").alias("PositiveTone"), 
                                             F.col("avg(NegativeTone)").alias("NegativeTone"),
                                             F.col("avg(Polarity)").alias("Polarity"), F.col("avg(ActivityDensity)").alias("ActivityDensity"), 
                                             F.col("avg(SelfDensity)").alias("SelfDensity"), F.col("avg(WordCount)").alias("WordCount"))
                                           
                          )
    
#     save_date = (filtered_df_result.groupby("date")
#                                   .agg((F.countDistinct("SourceCommonName")<2000).alias("except"))
#                 )
#     save_date = save_date.filter("except == False").select("date")
    
#     filtered_df = save_date.join(filtered_df_result, [save_date.date == filtered_df_result.date], 'inner').drop(save_date.date)
    return filtered_df_result


def avg_day_tone(filtered_df, name):
    """ """
    colname = f"{name.replace(' ', '_')}_tone"
    tone_df = (filtered_df.groupby(F.date_format("DATE", "y-MM-dd").alias("date"))
                          .agg((F.sum("Tone") / F.sum("WordCount")).alias(colname))
                          .select("date", f"{colname}")
                          .withColumn("date", F.to_date("date", format="y-MM-dd"))
                          .withColumn("date", F.col("date").cast("date"))
                          .orderBy(F.col("date").asc())
              )
    return tone_df


def get_col_avgs(df):
    exclude = [k for k, v in df.dtypes if v in ["date", "timestamp", "string", "SourceCommonName"]]
    avgs = df.select([F.avg(c).alias(c) for c in df.columns if c not in exclude]).collect()[0]
    return {c: avgs[c] for c in df.columns if c not in exclude}

# COMMAND ----------

def calculating_esg_values(start_date, end_date):
    """
    """
    data_path = f"dbfs:/mnt/esg/financial_report_data/GDELT_data_single_org/data_single_org"
    try:
        data = (spark.read.format("delta")
                     .option("header", "true")
                     .option("inferSchema", "true")
                     .load(data_path)
               )
        print("Data Loaded!")
    except:
        print("Data for these dates hasn't been generated!!!")
        return

    # Get all organizations
    print("Finding all Organizations")
    organizations = [x.Organization for x in data.select(
                     "Organization").distinct().collect()]
    
    # Get the overall tone
    print("Calculating Tones Over Time")
    #overall_tone = avg_day_tone(singleSource(data), "industry")
    overall_tone = avg_day_tone(data, "industry")
    esg_tones = {L: avg_day_tone(data.filter(f"{L} == True"), "industry")
                 for L in ["E", "S", "G"]}
    display(overall_tone)
    display(esg_tones['E'])
    display(esg_tones['S'])
    display(esg_tones['G'])
         
    del data   
    
    # Average to get overall scores
    print(organizations[0])
    print("Computing Overall Scores")
    scores = {}
    print("    Calculating overall tone")
    overall_scores = get_col_avgs(overall_tone)
    print("    Calculating esg tone")
    esg_scores = {L: get_col_avgs(tdf) for L, tdf in esg_tones.items()}
    
    print(overall_scores)
    print(esg_scores)
    print("DONE!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
base_dir = "dbfs:/mnt/esg/financial_report_data" 

# COMMAND ----------

def download_company_data(base_dir, start_date, end_date, org_name):
    _ = download_gdelt_data(start_date, end_date,org_name, save_csv=True)
    calculating_esg_values(start_date, end_date)

# COMMAND ----------

start_date = "2022-02-04"
end_date = "2022-02-08"
download_company_data(base_dir, start_date, end_date, "fortis")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Loading and cleaning all data
#    * loaded *   2022-02-04
#    * loaded *   2022-02-05
#    * loaded *   2022-02-06
#    * loaded *   2022-02-07
#    * loaded *   2022-02-08
# There are 1 data points for 1 organizations from 2022-02-04 to 2022-02-08
# Saving Data...
# Saved to dbfs:/mnt/esg/financial_report_data/GDELT_data_single_org/data_single_org
# Data Loaded!
# Finding all Organizations
# Calculating Tones Over Time
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>industry_tone</th></tr></thead><tbody><tr><td>2022-02-07</td><td>-0.0014071975886988395</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>industry_tone</th></tr></thead><tbody></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>industry_tone</th></tr></thead><tbody><tr><td>2022-02-07</td><td>-0.0014071975886988395</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>industry_tone</th></tr></thead><tbody><tr><td>2022-02-07</td><td>-0.0014071975886988395</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">fortis
# Computing Overall Scores
#     Calculating overall tone
#     Calculating esg tone
# {&#39;industry_tone&#39;: -0.0014071975886988395}
# {&#39;E&#39;: {&#39;industry_tone&#39;: None}, &#39;S&#39;: {&#39;industry_tone&#39;: -0.0014071975886988395}, &#39;G&#39;: {&#39;industry_tone&#39;: -0.0014071975886988395}}
# DONE!
# </div>

# %%
# !nano /databricks/python/lib/python3.8/site-packages/gdelt/parallel.py
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/bin/bash: nano: command not found
# </div>

# %%
''.join('2022-02-05'.split('-'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: &#39;20220205&#39;</div>
